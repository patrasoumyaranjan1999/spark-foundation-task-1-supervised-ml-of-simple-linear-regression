# %% [markdown]
# # SPARK FOUNDATION INTERNSHIP PROGRAM
# #TASK NO -1
# SUB-PREDICTION USING SUPERVISED MACHINE LEARNING
# DEPENDED VAIABLE IS-1:HOURS
# INDEPENDEND VARIABLE-1:SCORES
# THERE ARE TWO VARIABLES
# HERE INPUT IS HOURS AND OUTPUT IS SCORE

# %%
#IMPORT PACAKAGE FROM PYTHON LIBRARY
import pandas as pd
import numpy as np
df=pd.read_excel("D://DATA SCIENCE NOTE/Studentdata.xlsx")
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.isnull().sum()
df.max()
# Out:
# Hours      9.2
# Scores    95.0
# dtype: float64

# %%
print(Y)
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.xlabel("hours")
plt.ylabel("scores")
plt.legend("linear regression")

# %%
import matplotlib.pyplot as plt
plt.pie(X,Y)
plt.show()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
#create the simple linear regression model for the given data set
from sklearn.linear_model import LinearRegression
L=LinearRegression()

# %%
#train the model
L.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
L.coef_
# Out:
# array([9.77580339])

# %%
L.intercept_
# Out:
# 2.483673405373196

# %%
#prediction for x
Y_pred=L.predict(X)
Y_pred
# Out:
# array([26.92318188, 52.3402707 , 33.76624426, 85.57800223, 36.69898527,
#        17.14737849, 92.4210646 , 56.25059205, 83.62284155, 28.87834256,
#        77.75735951, 60.16091341, 46.47478866, 34.74382459, 13.23705714,
#        89.48832358, 26.92318188, 21.05769985, 62.11607409, 74.8246185 ,
#        28.87834256, 49.40752968, 39.63172629, 69.9367168 , 78.73493985])

# %%
#find the mean squared error
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y,Y_pred)
mse
# Out:
# 28.88273050924546

# %%
# fine r squared eeror
from sklearn.metrics import r2_score
rse=r2_score(Y,Y_pred)
rse
# Out:
# 0.9529481969048356

# %%
L.predict([[9.25]])
# Out:
# array([92.90985477])

# %%
#conclusion:-92.90 is the prediction value study  for 9.25 hours/day
